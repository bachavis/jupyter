# %%
[x**2 for x in range(0,6)]
# Out:
# [0, 1, 4, 9, 16, 25]

# %%
import pandas as pd
myDF = pd.DataFrame({'name': ['Barry', 'Megan', 'Alec', 'Tim', 'Harriet', 'Lindsay'],
                    'age': [12, 13, 15, 16, 19, 11]})
myDF
# Out:
#       name  age
# 0    Barry   12
# 1    Megan   13
# 2     Alec   15
# 3      Tim   16
# 4  Harriet   19
# 5  Lindsay   11

# %%
myDF['age']
# Out:
# 0    12
# 1    13
# 2    15
# 3    16
# 4    19
# 5    11
# Name: age, dtype: int64

# %%
myDF['name']
# Out:
# 0      Barry
# 1      Megan
# 2       Alec
# 3        Tim
# 4    Harriet
# 5    Lindsay
# Name: name, dtype: object

# %%
myDFRead = pd.read_csv('C:/Users/bchavis1/Downloads/IndiansRoster.csv')

# %%
myDFRead
# Out:
#               Name  Birth Date    Position  Height(in)  Weight (Lbs)
# 0      Jake Brigham    2/10/88     Pitcher          75           210
# 1       Gerrit Cole     9/8/90     Pitcher          76           240
# 2   Brandon Cumpton   11/16/88     Pitcher          74           220
# 3     John Holdzkom   10/19/87     Pitcher          79           225
# 4       Jay Jackson   10/27/87     Pitcher          73           195
# 5      Nick Kingham    11/8/91     Pitcher          77           220
# 6       Josh Kinney    3/31/79     Pitcher          72           220
# 7       Vin Mazzaro    9/27/86     Pitcher          74           220
# 8       A.J. Morris    12/1/86     Pitcher          74           185
# 9     Wirfin Obispo    9/26/84     Pitcher          74           215
# 10      Andy Oliver    12/3/87     Pitcher          75           215
# 11     Rafael Perez    5/15/82     Pitcher          75           195
# 12     Casey Sadler    7/13/90     Pitcher          76           215
# ...
