# %%
import pandas as pd
import numpy as np

# %%
banjo = pd.read_csv('C:/Users/bchavis1/Downloads/BanjoPlayers.csv')
banjo
# Out:
#     ID                      Name BanjoPlayer  \
# 0   20               Taylor Rice          No
# 1   12              Earl Scruggs         Yes
# 2   14             Geoff Rickley          No
# 3    2               Samuel Beam         Yes
# 4   13              Adam Lazarra          No
# 5   11             Ralph Stanley         Yes
# 6    5            Chris Luedecke         Yes
# 7    4                Alex Ebert          No
# 8   19  William Elliott Whitmore         Yes
# 9   18          Bobby Earl Davis         Yes
# 10  16                Bela Fleck         Yes
# 11   7             Justin Vernon          No
# 12   6          Kristian Matsson         Yes
# 13   9             Jack Antonoff          No
# 14  17               Ketch Secor          No
# 15   3                Nate Ruess          No
# 16  10             Critter Fuqua          No
# 17   1            Sufjan Stevens         Yes
# 18   8               Scott Avett         Yes
# 19  15             Willie Watson         Yes
#
# ...

# %%
banjo.sample(10, replace = False)
# Out:
#     ID                      Name BanjoPlayer  \
# 14  17               Ketch Secor          No
# 17   1            Sufjan Stevens         Yes
# 1   12              Earl Scruggs         Yes
# 19  15             Willie Watson         Yes
# 0   20               Taylor Rice          No
# 7    4                Alex Ebert          No
# 5   11             Ralph Stanley         Yes
# 9   18          Bobby Earl Davis         Yes
# 8   19  William Elliott Whitmore         Yes
# 16  10             Critter Fuqua          No
#
#                                      Band
# 14                 Old Crow Medicine Show
# 17                         Sufjan Stevens
# 1                     Foggy Mountain Boys
# 19                 Old Crow Medicine Show
# 0                       The Local Natives
# 7   Edwarde Sharpe and the Magnetic Zeros
# 5                    The Stanley Brothers
# 9                       The Earl Brothers
# 8                William Elliott Whitmore
# ...

# %%
sample1 = banjo.sample(10, replace = False)
sample1
# Out:
#     ID              Name BanjoPlayer                                   Band
# 17   1    Sufjan Stevens         Yes                         Sufjan Stevens
# 6    5    Chris Luedecke         Yes                       Old Man Luedecke
# 3    2       Samuel Beam         Yes                          Iron and Wine
# 12   6  Kristian Matsson         Yes               The Tallest Man on Earth
# 1   12      Earl Scruggs         Yes                    Foggy Mountain Boys
# 0   20       Taylor Rice          No                      The Local Natives
# 19  15     Willie Watson         Yes                 Old Crow Medicine Show
# 7    4        Alex Ebert          No  Edwarde Sharpe and the Magnetic Zeros
# 2   14     Geoff Rickley          No                               Thursday
# 15   3        Nate Ruess          No                                   Fun.

# %%
np.random.seed(123)
banjo.sample(10, replace = False)
# Out:
#     ID                      Name BanjoPlayer  \
# 14  17               Ketch Secor          No
# 5   11             Ralph Stanley         Yes
# 4   13              Adam Lazarra          No
# 17   1            Sufjan Stevens         Yes
# 8   19  William Elliott Whitmore         Yes
# 7    4                Alex Ebert          No
# 19  15             Willie Watson         Yes
# 12   6          Kristian Matsson         Yes
# 0   20               Taylor Rice          No
# 15   3                Nate Ruess          No
#
#                                      Band
# 14                 Old Crow Medicine Show
# 5                    The Stanley Brothers
# 4                      Taking Back Sunday
# 17                         Sufjan Stevens
# 8                William Elliott Whitmore
# 7   Edwarde Sharpe and the Magnetic Zeros
# 19                 Old Crow Medicine Show
# 12               The Tallest Man on Earth
# 0                       The Local Natives
# ...
